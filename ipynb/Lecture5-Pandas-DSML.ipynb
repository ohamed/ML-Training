# %% [markdown]
# ## Pandas
# - This Jupyter Notebook (NB) shows how to create a Pandas DataFrame from an online CSV file.
# - <a href="http://rcs.bu.edu/examples/python/DataAnalysis" target="_blank">Download CSV files</a>

# %%
import pandas as pd

# %%
url = "http://rcs.bu.edu/examples/python/DataAnalysis/Salaries.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.sum(axis=0)
# Out:
# rank          ProfProfProfProfProfProfAssocProfProfProfProfP...
# discipline    BAAABAAAAABBBBBBBBAABAAAABAABBBBABBBBABBAABBBB...
# phd                                                        1537
# service                                                    1174
# sex           MaleMaleMaleMaleMaleMaleMaleMaleMaleMaleMaleMa...
# salary                                                  8425855
# dtype: object

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %%
type(df[['rank','salary']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_sub = df[ df['salary'] > 120000 ]

# %%
df_sub.shape
# Out:
# (25, 6)

# %%
flights = pd.read_csv("http://rcs.bu.edu/examples/python/DataAnalysis/flights.csv")

# %%
flights
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 160749  2013      9   30    2105.0       -1.0    2329.0      -25.0      UA
# 160750  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 160751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 160752  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 160753  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
flights.sample(20)
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 75688   2013      3   25    1132.0       -8.0    1505.0       20.0      AA
# 5625    2013      1   14    1658.0       -2.0    2124.0      -40.0      DL
# 1090    2013      1    3    1453.0       23.0    1754.0      -21.0      DL
# 107659  2013      6    4    1947.0       -3.0    2307.0      -18.0      UA
# 59811   2013      2   17    1405.0       -2.0    1652.0       -9.0      UA
# 39982   2013     12    1    1900.0        0.0    2216.0        4.0      UA
# 32050   2013     11   13    1055.0       -5.0    1349.0      -18.0      DL
# 110880  2013      6   12     556.0       -4.0     705.0      -22.0      UA
# 151339  2013      9    9    1227.0       12.0    1525.0       16.0      DL
# 71415   2013      3   15    1547.0        2.0    1823.0       -1.0      DL
# 56996   2013      2   10    1954.0       -6.0    2123.0        9.0      US
# ...

# %%
flights.isnull().sample(100)
# Out:
#          year  month    day  dep_time  dep_delay  arr_time  arr_delay  \
# 42954   False  False  False     False      False     False      False
# 89740   False  False  False     False      False     False      False
# 85197   False  False  False     False      False     False      False
# 91550   False  False  False     False      False     False      False
# 86088   False  False  False     False      False     False      False
# ...       ...    ...    ...       ...        ...       ...        ...
# 72118   False  False  False     False      False     False      False
# 92743   False  False  False     False      False     False      False
# 146715  False  False  False     False      False     False      False
# 90989   False  False  False     False      False     False      False
# 95325   False  False  False     False      False     False      False
#
#         carrier  tailnum  flight  origin   dest  air_time  distance   hour  \
# ...

# %%
flights[flights.isnull().any(axis=1)].head
# Out:
# (2827, 16)
